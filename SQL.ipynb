# %%
import pandas as pd

# %%
spotify = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-01-21/spotify_songs.csv")

# %%
spotify.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
# 2                    All the Time (Don Diablo Remix)               2019-07-05
# 3                        Call You Mine - The Remixes               2019-07-19
# 4            Someone You Loved (Future Humans Remix)               2019-03-05
#
#   playlist_name             playlist_id playlist_genre  ... mode  speechiness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...    1       0.0583
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...    1       0.0373
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...    0       0.0742
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...    1       0.1020
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...    1       0.0359
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0        0.1020          0.000000    0.0653    0.518  122.036       194754
# 1        0.0724          0.004210    0.3570    0.693   99.972       162600
# 2        0.0794          0.000023    0.1100    0.613  124.008       176616
# 3        0.0287          0.000009    0.2040    0.277  121.956       169093
# 4        0.0803          0.000000    0.0833    0.725  123.976       189052
#
#    ID  id
# 0   0   0
# 1   1   1
# 2   2   2
# 3   3   3
# 4   4   4
#
# [5 rows x 25 columns]

# %%
spotify.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'ID', 'id'],
#       dtype='object')

# %% [markdown]
# ### track tables

# %%
track1 = spotify.iloc[:, 0:5]
track2 = spotify.loc[:, 'danceability':]

# %%
track = pd.concat([track1, track2], axis = 1).drop_duplicates()
track.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  danceability  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx         0.748
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6         0.726
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4         0.675
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6         0.718
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ         0.650
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.916    6    -2.634     1       0.0583        0.1020          0.000000
# 1   0.815   11    -4.969     1       0.0373        0.0724          0.004210
# 2   0.931    1    -3.432     0       0.0742        0.0794          0.000023
# 3   0.930    7    -3.778     1       0.1020        0.0287          0.000009
# 4   0.833    1    -4.672     1       0.0359        0.0803          0.000000
#
#    liveness  valence    tempo  duration_ms
# 0    0.0653    0.518  122.036       194754
# 1    0.3570    0.693   99.972       162600
# 2    0.1100    0.613  124.008       176616
# 3    0.2040    0.277  121.956       169093
# 4    0.0833    0.725  123.976       189052

# %%
def is_pk(df, key):
    '''
    check if the checked column is the primary key
    the column is PK if it uniquely identifies each row of the dataframe
    
    Parameters:
    ---------------
    df: the dataframe
    key: the candidate column to check if it is primary key
    '''
    
    if len(set(df.loc[:,key])) == df.shape[0]:
        return True
    else:
        return False

# %%
is_pk(track, 'track_id')
# Out:
# True

# %% [markdown]
# ## album tables
# we need to include 'track_album_id', 'track_album_name', 'track_album_release_date'

# %%
album = spotify.loc[:, 'track_album_id':'track_album_release_date'].drop_duplicates()
album.columns = ['album_id', 'album_name','release_date']
album.head()
# Out:
#                  album_id                                         album_name  \
# 0  2oCs0DGTsRO98Gh5ZSl2Cx  I Don't Care (with Justin Bieber) [Loud Luxury...
# 1  63rPSO264uRjW1X5E6cWv6                    Memories (Dillon Francis Remix)
# 2  1HoSmj2eLcsrR0vE9gThr4                    All the Time (Don Diablo Remix)
# 3  1nqYsOef1yKKuGOVchbsk6                        Call You Mine - The Remixes
# 4  7m7vv9wlQ4i0LFuJiE2zsQ            Someone You Loved (Future Humans Remix)
#
#   release_date
# 0   2019-06-14
# 1   2019-12-13
# 2   2019-07-05
# 3   2019-07-19
# 4   2019-03-05

# %%
is_pk(album,'album_id')
# Out:
# True

# %% [markdown]
# ## Playlist and genres tables
# * columns related to playlist include 'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre'
# * we need a seperate table relates id and name, and a table for id relating to genres
# * We also need a table relates which track belongs to the playlist
# * Notice there are 'playlist_genre', 'playlist_subgenre' that may have some dependency, so we also need a seperate table to realte these two.

# %%
genres = spotify.loc[:, ['playlist_genre', 'playlist_subgenre']].drop_duplicates()
genres.head()
# Out:
#      playlist_genre playlist_subgenre
# 0               pop         dance pop
# 1298            pop     post-teen pop
# 2427            pop        electropop
# 3835            pop   indie poptimism
# 5507            rap           hip hop

# %%
genres.groupby('playlist_genre').count()
# Out:
#                 playlist_subgenre
# playlist_genre
# edm                             4
# latin                           4
# pop                             4
# r&b                             4
# rap                             4
# rock                            4

# %%
genres.groupby('playlist_subgenre').count() 
#if we know the subgenre, then we can deduce its genre. but not the other way
#so we only need to create a table relates playlist id and subgenre
# Out:
#                            playlist_genre
# playlist_subgenre
# album rock                              1
# big room                                1
# classic rock                            1
# dance pop                               1
# electro house                           1
# electropop                              1
# gangster rap                            1
# hard rock                               1
# hip hop                                 1
# hip pop                                 1
# indie poptimism                         1
# latin hip hop                           1
# latin pop                               1
# neo soul                                1
# new jack swing                          1
# permanent wave                          1
# pop edm                                 1
# post-teen pop                           1
# progressive electro house               1
# reggaeton                               1
# southern hip hop                        1
# trap                                    1
# tropical                                1
# urban contemporary                      1

# %%
playlist_name = spotify.loc[:, ['playlist_id', 'playlist_name']].drop_duplicates()
playlist_name.head()
# Out:
#                 playlist_id   playlist_name
# 0    37i9dQZF1DXcZDD7cfEKhW       Pop Remix
# 70   37i9dQZF1DWZQaaqNMbbXa       Dance Pop
# 167  37i9dQZF1DX2ENAPP1Tyed      Dance Room
# 223  37i9dQZF1DWSJHnPb1f0X3          Cardio
# 272  37i9dQZF1DX6pH08wMhkaI  Dance Pop Hits

# %%
is_pk(playlist_name, 'playlist_id')
# Out:
# True

# %%
playlist = spotify.loc[:,['playlist_id', 'playlist_subgenre']].drop_duplicates().reset_index()
playlist['index'] = playlist.index
playlist.columns = ['playlist_idx', 'id', 'subgenre']
playlist.head()
# Out:
#    playlist_idx                      id   subgenre
# 0             0  37i9dQZF1DXcZDD7cfEKhW  dance pop
# 1             1  37i9dQZF1DWZQaaqNMbbXa  dance pop
# 2             2  37i9dQZF1DX2ENAPP1Tyed  dance pop
# 3             3  37i9dQZF1DWSJHnPb1f0X3  dance pop
# 4             4  37i9dQZF1DX6pH08wMhkaI  dance pop

# %%
is_pk(playlist, 'playlist_idx')
# Out:
# True

# %%
track1 = spotify.loc[:, ['track_id', 'playlist_id', 'playlist_subgenre']].drop_duplicates()

# %%
playlist_track = pd.merge(track1, playlist, how = 'inner', left_on = ['playlist_id', 'playlist_subgenre'],
        right_on=['id', 'subgenre']).loc[:, ['track_id', 'playlist_idx']].drop_duplicates().reset_index()
playlist_track['index'] = playlist_track.index
playlist_track.columns = ['playlist_track_id', 'track_id', 'playlist_idx']
playlist_track.head()
# Out:
#    playlist_track_id                track_id  playlist_idx
# 0                  0  6f807x0ima9a1j3VPbc7VN             0
# 1                  1  0r7CVbZTWZgbTCYdfa2P31             0
# 2                  2  1z1Hg7Vb0AhHDiEmnDE79l             0
# 3                  3  75FpbthrwQmzHlBJLuGdC7             0
# 4                  4  1e8PAfcKUYoKkxPhrHqw4x             0

# %%
is_pk(playlist_track, 'playlist_track_id')
# Out:
# True

# %%
playlist_track.columns
# Out:
# Index(['playlist_track_id', 'track_id', 'playlist_idx'], dtype='object')

# %% [markdown]
# ## save SQL

# %%
# %load_ext sql
# %sql sqlite:///spotify.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# DROP TABLE IF EXISTS Tracks;
# DROP TABLE IF EXISTS Albums;
# DROP TABLE IF EXISTS Genres;
# DROP TABLE IF EXISTS Playlist_Name;
# DROP TABLE IF EXISTS Playlist;
# DROP TABLE IF EXISTS Playlist_Track;
#
# CREATE TABLE Tracks (
#     track_id TEXT NOT NULL PRIMARY KEY,
#     track_name TEXT,
#     track_artist TEXT,
#     track_popularity INTEGER NOT NULL,
#     track_album_id TEXT NOT NULL,
#     danceability REAL NOT NULL,
#     energy REAL NOT NULL,
#     key INTEGER NOT NULL,
#     loudness REAL NOT NULL,
#     mode INTEGER NOT NULL,
#     speechiness REAL NOT NULL,
#     acousticness REAL NOT NULL,
#     instrumentalness REAL NOT NULL,
#     liveness REAL NOT NULL,
#     valence REAL NOT NULL,
#     tempo REAL NOT NULL,
#     duration_ms INTEGER NOT NULL,
#         FOREIGN KEY (track_album_id) REFERENCES Albums(album_id)
# );
#
# CREATE TABLE Albums (
#     album_id TEXT NOT NULL PRIMARY KEY,
#     album_name TEXT,
#     release_date TEXT
# );
#
# CREATE TABLE Genres(
#     playlist_genre TEXT,
#     playlist_subgenre TEXT NOT NULL PRIMARY KEY
# );
#
# CREATE TABLE Playlist_Name(
#     playlist_id TEXT NOT NULL PRIMARY KEY,
#     playlist_name TEXT NOT NULL
# );
# CREATE TABLE Playlist(
#     playlist_idx INTEGER NOT NULL PRIMARY KEY,
#     id TEXT NOT NULL,
#     subgenre TEXT NOT NULL,
#         FOREIGN KEY (id) REFERENCES Playlist_Name(playlist_id),
#         FOREIGN KEY (subgenre) REFERENCES Genres(playlist_subgenre)
# );
# CREATE TABLE Playlist_Track(
#     playlist_track_id INTEGER NOT NULL PRIMARY KEY,
#     track_id TEXT NOT NULL,
#     playlist_idx INTEGER NOT NULL,
#         FOREIGN KEY(track_id) REFERENCES Tracks(track_id),
#         FOREIGN KEY(playlist_idx) REFERENCES Playlist(playlist_idx)
# );
# Out:
#  * sqlite:///spotify.db
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %%
import sqlite3
con = sqlite3.connect('spotify.db')

# %%
track.to_sql('Tracks', con, if_exists='replace', index = False)
album.to_sql('Albums', con, if_exists='replace', index = False)
genres.to_sql('Genres', con, if_exists='replace', index = False)
playlist_name.to_sql('Playlist_Name', con, if_exists = 'replace', index = False)
playlist.to_sql('Playlist', con, if_exists = 'replace', index = False)
playlist_track.to_sql('Playlist_Track', con, if_exists = 'replace', index = False)

# %%
sql = '''
SELECT DISTINCT Playlist_Name.playlist_name
FROM Tracks
LEFT JOIN Playlist_Track ON Tracks.track_id = Playlist_Track.track_id
LEFT JOIN Playlist ON Playlist.playlist_idx = Playlist_Track.playlist_idx
LEFT JOIN Playlist_Name ON Playlist.id = Playlist_Name.playlist_id
WHERE instrumentalness > 0.5
ORDER BY instrumentalness DESC
'''

# %%
pd.read_sql(sql, con)
# Out:
#                                          playlist_name
# 0                                       90s Dance Hits
# 1                                 RUSSIAN Gangster Rap
# 2                  The Queen - La Discografia Completa
# 3                                     Classic Rock Now
# 4                                              EDM/POP
# 5                            Supernatural Classic Rock
# 6    The 1950s/1960s/1970s/1980s/1990s/2000s/2010s ...
# 7                     Japanese Funk/Soul/NEO/Jazz/Acid
# 8                 80s Pop & Rock Hits and Album Tracks
# 9                                      Club Mix 2020 🍹
# 10                                         Lo-Fi Beats
# 11                                Indie/Jazz Poptimism
# 12                             Jeff Seid Electro House
# 13                                     Tropical Nights
# 14                                    INDIE POP! TUNES
# 15                                        URBAN NATION
# 16                                ALPAS Music Festival
# 17                                  Pop Warmup 130 BPM
# 18                                      Vibra Tropical
# 19                                      Tropical Vibes
# 20                                      Pop Dance Hits
# 21                                          Great Pops
# 22                               Top Urban Underground
# 23                                           Lush Lofi
# 24                                           Dance Pop
# 25   Techno House 2020 👽 Best Collection 👻 Top DJ’s...
# 26                                  3rd Coast Classics
# 27                                   Afro Psychedelica
# 28               Latest Hits 2020 - Pop, Hip Hop & RnB
# 29                                    2000's hard rock
# ..                                                 ...
# 226                                 urban CONTEMPORARY
# 227                                         Nasty Bits
# 228                     Electro/Progressive/Club House
# 229                                 Urban Contemporary
# 230                             Workday: Rock Classics
# 231                            The Cranberries Best Of
# 232              New Jack Swing/ R&B Hits: 1987 - 2002
# 233             90s Gangsta Rap / Top Hip-hop Classics
# 234                                        Locker Room
# 235                               Minitruckin Playlist
# 236                                        Trap Nation
# 237                              This Is Guns N' Roses
# 238                  Soda Stereo – El Ultimo Concierto
# 239                     Dr. Q's Prescription Playlist💊
# 240                                    Pop EDM Remixes
# 241                            House Of The Rising Sun
# 242                                      Rock Classics
# 243                            Hard Rock Cafe Classics
# 244                                   Orgulho Tropical
# 245                           Electro Pop | Electropop
# 246                             Neo-Soul / Soulful R&B
# 247                              Electro Swing Top 100
# 248                                            HIP&HOP
# 249  Fitness Workout Electro | House | Dance | Prog...
# 250                  Big Room House | Festival Bangers
# 251  90s R&B - The BET Planet Groove/Midnight Love Mix
# 252  Swingbeat (old skool), New Jack Swing, R&B, Hi...
# 253                 Epic Bass Drops | Best House Mixes
# 254                                    The Black Album
# 255                                      post teen pop
#
# [256 rows x 1 columns]

# %%
pip install tabulate
# Out:
# Collecting tabulate
#   Downloading tabulate-0.8.7-py3-none-any.whl (24 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.8.7
# Note: you may need to restart the kernel to use updated packages.

# %%
from tabulate import tabulate

# %%
print(tabulate(pd.read_sql(sql, con).head(), tablefmt="pipe", headers="keys"))
# Out:
# |    | playlist_name                       |
# |---:|:------------------------------------|
# |  0 | 90s Dance Hits                      |
# |  1 | RUSSIAN Gangster Rap                |
# |  2 | The Queen - La Discografia Completa |
# |  3 | Classic Rock Now                    |
# |  4 | EDM/POP                             |
